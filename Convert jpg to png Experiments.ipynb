# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def render_image(image):
    plt.figure(figsize = (8, 6))
    plt.imshow(image)
    plt.axis('off')
    plt.show()

def convert_to_RGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

def convert_to_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
image = cv2.imread('retina.jpg')
gray = convert_to_grayscale(image)

retina, mask = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
kernel = np.ones((9, 9), np.uint8)
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

result = image.copy()
result = cv2.cvtColor(result, cv2.COLOR_BGR2BGRA)
result[:, :, 3] = mask

cv2.imwrite('retina_cropped.png', result)
# Out:
# True

# %%
render_image(convert_to_RGB(image))

# %%
retina_cropped = cv2.imread('retina_cropped.png')
render_image(convert_to_RGB(retina_cropped))

# %%
image = cv2.imread('t shirt with man.jpg')
gray = convert_to_grayscale(image)

retina, mask = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
kernel = np.ones((9, 9), np.uint8)
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

result = image.copy()
result = cv2.cvtColor(result, cv2.COLOR_BGR2BGRA)
result[:, :, 3] = mask

cv2.imwrite('t shirt with man cropped.png', result)
# Out:
# True

# %%
t_shirt_with_man_cropped = cv2.imread('t shirt with man cropped.png')
render_image(convert_to_RGB(t_shirt_with_man_cropped))

# %%
image = cv2.imread('white t shirt 2.jpg')
gray = convert_to_grayscale(image)

retina, mask = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
kernel = np.ones((9, 9), np.uint8)
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

result = image.copy()
result = cv2.cvtColor(result, cv2.COLOR_BGR2BGRA)
result[:, :, 3] = mask

cv2.imwrite('white t shirt 2 cropped.png', result)
# Out:
# True

# %%
render_image(convert_to_RGB(image))

# %%
t_shirt_with_man_cropped = cv2.imread('white t shirt 2 cropped.png')
render_image(convert_to_RGB(t_shirt_with_man_cropped))
